# %%
# code to isolate unique mutations found in resistant strain from mutations in common with the WT

import pandas as pd

dfBAA47_WT = pd.read_excel(r"C:\Users\best4\OneDrive\Documents\University of Oklahoma\Sequencing Data\BAA47 Mutations.xlsx")

dfBAA47_R1 = pd.read_excel(r"C:\Users\best4\OneDrive\Documents\University of Oklahoma\Sequencing Data\BAA47-R1 Mutations.xlsx")

cond = dfBAA47_R1['gene'].isin(dfBAA47_WT['gene'])

dfBAA47_R1_Placeholder = dfBAA47_R1.drop(dfBAA47_R1[cond].index, inplace = True)

print("These are the genes that are changed in the R1 Mutant:")
dfBAA47_R1
# Out:
# These are the genes that are changed in the R1 Mutant:
#    evidence  position mutation             annotation      gene  \
# 4        RA    480675      C→T       W151* (TGG→TAG)   PA0429 ←
# 29       RA   2210020      +TG  coding (1287/3138 nt)  PA2018 ←
# 40       RA   2817559      G→A        P37P (CCG→CCA)   PA2500 →
# 45       RA   3532701      G→A        H39Y (CAT→TAT)     wbpI ←
# 46       RA   3538907      G→A        P73L (CCA→CTA)      wzy ←
#
#                                           description
# 4                                hypothetical protein
# 29  Resistance‑Nodulation‑Cell Division (RND) mult...
# 40  probable major facilitator superfamily (MFS) t...
# 45           UDP‑N‑acetylglucosamine 2‑epimerase WbpI
# 46                        B‑band O‑antigen polymerase

# %%
# code to isolate unique mutations found in resistant strain from mutations in common with the WT

import pandas as pd

dfBAA47_WT = pd.read_excel(r"C:\Users\best4\OneDrive\Documents\University of Oklahoma\Sequencing Data\BAA47 Mutations.xlsx")

dfBAA47_R2 = pd.read_excel(r"C:\Users\best4\OneDrive\Documents\University of Oklahoma\Sequencing Data\BAA47-R2 Mutations.xlsx")

cond = dfBAA47_R2['gene'].isin(dfBAA47_WT['gene'])

dfBAA47_R2_Placeholder = dfBAA47_R2.drop(dfBAA47_R2[cond].index, inplace = True)

print("These are the genes that are changed in the R2 Mutant:")
dfBAA47_R2
# Out:
# These are the genes that are changed in the R2 Mutant:
#    evidence  position mutation        annotation      gene  \
# 4        RA    480675      C→T  W151* (TGG→TAG)   PA0429 ←
# 39       RA   2817559      G→A   P37P (CCG→CCA)   PA2500 →
# 44       RA   3532701      G→A   H39Y (CAT→TAT)     wbpI ←
# 45       RA   3538907      G→A   P73L (CCA→CTA)      wzy ←
#
#                                           description
# 4                                hypothetical protein
# 39  probable major facilitator superfamily (MFS) t...
# 44           UDP‑N‑acetylglucosamine 2‑epimerase WbpI
# 45                        B‑band O‑antigen polymerase
